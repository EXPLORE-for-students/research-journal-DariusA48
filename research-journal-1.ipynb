# %% [markdown]
# # Research Notebook
# ## your name here
# ## Date:

# %% [markdown]
# Anirudh- Put in your names and details here.

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# -became acquainted with programs and packages that were new to me, starting on coding
#
# ## Motivation:
#
# -certain packages were not functioning as expected.
# -Our group has decided to have code for the intitial draft that uses the schwarzschild metric before adding new elements.

# %% [markdown]
# Anirudh:- could you please elaborate on the research activity and the motivation behind it? The current information does not provide enough detail about the research component. Additionally, please mention that we were in the process of familiarizing ourselves with specific programs and packages. It would be helpful to specify which programming languages (e.g., Python, R) and what types of packages (e.g., data analysis libraries, visualization tools) were used, along with the purpose of utilizing them in our research.

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# I learned how to use new programs for convenience later down the line such as vscode, and creating/using a virtual environment within it to assist with use of certain packages. Progress in coding was slow due to issued regarding python package OGRePy. Getting it to be compatible with versions of python and numpy proved to be a little more complicated than I had expected on my machine. Aside from that, code was started for certain elements within our group project draft. Code written was regarding the effective potential of a body near a black hole in two different cases: null and time like. Null refers to the null geodesic, describing effective potential of a massless particle (such as a photon) near a black hole, while timelike refers to a particle with mass. Additionally, the differential equations were solved to determine extrema of the equations.

# %% [markdown]
# Anirudh- I feel this could be structured a little bit better.

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# I now have a functional virtual environemnt with finctional packages and some results on code, including effective potential plots and extrema.
#
# ![image.png](attachment:76e7f068-2c84-4883-8e4b-acada97961fa.png)
#
# ![image.png](attachment:18a9dbb2-a742-45b7-9b61-6c1bb772fc03.png)
#
# Extrema:
#
# #Null
# M=1
# L=3
# r = gr.sym("r", nonnegative=True)
#
# h=r**2
# f=1-2*M/r
#
#
# #define symbols for differentiation
# sigma = gr.sym("sigma")
# L = gr.sym("L")
#
# V_eff = -f*( sigma - L**2 /h)
# dV_eff_dr = gr.s.diff(V_eff, r).subs(sigma, 0)
# extrema = gr.s.solve(dV_eff_dr, r)
#
# print('extrema: r=', extrema)
#
#
# #timelike
# L=3
#
#
# V_eff = -f*( sigma - L**2 /h)
# dV_eff_dr = gr.s.diff(V_eff, r).subs(sigma, 1)
# extrema = gr.s.solve(dV_eff_dr, r)
# print('extrema: r=', extrema)
#
# ![image.png](attachment:da96e5a6-1fe4-4c2c-89db-650dc7a64502.png)

# %% [markdown]
# Anirudh- The equations can be written down as math blocks, which looks a lot better. Please look at the example bellow.
#
# $$
#   \int_0^\infty \frac{x^3}{e^x-1}\,dx = \frac{\pi^4}{15}
# $$
#
# I have added the equations in kind of latex format and then inclosed it in *$* Symbol.

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# -Continue with coding elements of the draft to get a better understanding  of the behaviour of black holes under the Schwarzschild metric
# -Read papers shared in the group to begin to understand the metric we will be converting to, describing quantum black holes.

# %% [markdown]
# Anirudh -Need to elaborate more on the tasks which was done for the week.

# %% [markdown]
# # 5. Bibliography
#
# Your references here

# %% [markdown]
# NO Reference ?

# %% [markdown]
# | Category       | Points      |
# | ------------- |:------------:|
# | Formatting    |       1       |
# | Experience    |       1       |
# | What?         |       1       |
# | So what?      |       2       |
# | Now what?     |       2       |
# | Bibliography  |       0       |
# | Style         |       3       |
# | Total         |       10      |
